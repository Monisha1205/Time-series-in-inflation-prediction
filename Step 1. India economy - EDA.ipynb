# %%
from Univariate import Univariate
obj= Univariate()
import pandas as pd 
dataset=pd.read_csv("indianEco.csv")
dataset
# Out:
#     Year Country Name  GDP (current US$)    GDP per capita (current US$)   \
# 0   1960        India        3.702988e+10                              82
# 1   1961        India        3.923244e+10                              85
# 2   1962        India        4.216148e+10                              90
# 3   1963        India        4.842192e+10                             101
# 4   1964        India        5.648029e+10                             116
# ..   ...          ...                 ...                             ...
# 56  2016        India        2.294798e+12                            1733
# 57  2017        India        2.651473e+12                            1981
# 58  2018        India        2.702930e+12                            1997
# 59  2019        India        2.831552e+12                            2101
# 60  2020        India        2.667688e+12                            1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# 0                    0.00                                      6.83
# 1                    3.72                                      5.96
# 2                    2.93                                      6.03
# 3                    5.99                                      5.91
# 4                    7.45                                      5.69
# ..                    ...                                       ...
# 56                   8.26                                     20.92
# 57                   6.80                                     21.95
# 58                   6.53                                     23.69
# 59                   4.04                                     21.27
# 60                  -7.25                                     19.10
#
#     Exports of goods and services (% of GDP)  \
# 0                                       4.46
# 1                                       4.30
# 2                                       4.17
# 3                                       4.28
# 4                                       3.73
# ..                                       ...
# 56                                     19.16
# 57                                     18.79
# 58                                     19.93
# 59                                     18.69
# 60                                     18.71
#
#      Total reserves (includes gold, current US$)   \
# 0                                    6.745366e+08
# 1                                    6.663571e+08
# 2                                    5.127918e+08
# 3                                    6.078625e+08
# 4                                    4.991451e+08
# ..                                            ...
# 56                                   3.616943e+11
# 57                                   4.126138e+11
# 58                                   3.991672e+11
# 59                                   4.634699e+11
# 60                                   5.902274e+11
#
#     Inflation, consumer prices (annual %)  Population, total  \
# 0                                    1.78          445954579
# 1                                    1.70          456351876
# 2                                    3.63          467024193
# 3                                    2.95          477933619
# 4                                   13.36          489059309
# ..                                    ...                ...
# 56                                   4.95         1338636340
# 57                                   3.33         1354195680
# 58                                   3.94         1369003306
# 59                                   3.73         1383112050
# 60                                   6.62         1396387127
#
#     Population growth (annual %)  Life expectancy at birth, total (years)
# 0                           2.31                                    41.13
# 1                           2.33                                    41.74
# 2                           2.34                                    42.34
# 3                           2.34                                    42.94
# 4                           2.33                                    43.57
# ..                           ...                                      ...
# 56                          1.19                                    68.67
# 57                          1.16                                    68.97
# 58                          1.09                                    69.27
# 59                          1.03                                    69.50
# 60                          0.96                                    69.73
#
# [61 rows x 12 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 12 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Year                                           61 non-null     int64
#  1   Country Name                                   61 non-null     object
#  2   GDP (current US$)                              61 non-null     float64
#  3    GDP per capita (current US$)                  61 non-null     int64
#  4   GDP growth (annual %)                          61 non-null     float64
#  5   Imports of goods and services (% of GDP)       61 non-null     float64
#  6   Exports of goods and services (% of GDP)       61 non-null     float64
#  7    Total reserves (includes gold, current US$)   61 non-null     float64
#  8   Inflation, consumer prices (annual %)          61 non-null     float64
#  9   Population, total                              61 non-null     int64
#  10  Population growth (annual %)                   61 non-null     float64
#  11  Life expectancy at birth, total (years)        61 non-null     float64
# dtypes: float64(8), int64(3), object(1)
# memory usage: 5.8+ KB

# %%
qual, quan = obj.Quanqual(dataset)

# %%
qual
# Out:
# ['Country Name']

# %%
quan
# Out:
# ['Year',
#  'GDP (current US$) ',
#  ' GDP per capita (current US$) ',
#  'GDP growth (annual %)',
#  'Imports of goods and services (% of GDP)',
#  'Exports of goods and services (% of GDP)',
#  ' Total reserves (includes gold, current US$) ',
#  'Inflation, consumer prices (annual %)',
#  'Population, total',
#  'Population growth (annual %)',
#  'Life expectancy at birth, total (years)']

# %%
des_data = obj.Univariate(dataset, quan)

# %%
des_data
# Out:
#                      Year          GDP (current US$)   \
# mean               1990.0         658472481990.051025
# median             1990.0         288208430383.960022
# mode                 1960              37029883876.18
# Q1:25th            1975.0          99525899116.050003
# Q2:50th            1990.0         288208430383.960022
# Q3:75th            2005.0         820381595512.900024
# 99th               2019.4        2754378720384.271973
# Q4:100th             2020        2831552222519.990234
# IQR                  30.0         720855696396.849976
# min                  1960              37029883876.18
# max                  2020        2831552222519.990234
# lower whisker      1930.0        -981757645479.224854
# upper whisker      2050.0        1901665140108.174805
# skewness              0.0                    1.487064
# kurtosis             -1.2                    0.937482
# var            315.166667  660904882452575979307008.0
# std             17.752934         812960566357.665283
#
#                GDP per capita (current US$)  GDP growth (annual %)  \
# mean                              575.557377              4.938197
# median                                 340.0                  5.53
# mode                                      90                  7.86
# Q1:25th                                161.0                  3.72
# Q2:50th                                340.0                  5.53
# Q3:75th                                715.0                  7.45
# 99th                                  2038.6                 9.342
# Q4:100th                                2101                  9.63
# IQR                                    554.0                  3.73
# min                                       82                 -7.25
# max                                     2101                  9.63
# lower whisker                         -670.0                -1.875
# upper whisker                         1546.0                13.045
# skewness                            1.382711             -1.507248
# kurtosis                            0.621198               2.89915
# var                             341148.35082             11.188295
# std                               584.079062              3.344891
#
#               Imports of goods and services (% of GDP)  \
# mean                                         12.746393
# median                                            8.57
# mode                                              3.71
# Q1:25th                                           6.59
# Q2:50th                                           8.57
# Q3:75th                                          19.64
# 99th                                            31.152
# Q4:100th                                         31.26
# IQR                                              13.05
# min                                               3.71
# max                                              31.26
# lower whisker                                  -12.985
# upper whisker                                   39.215
# skewness                                      0.894044
# kurtosis                                     -0.564755
# var                                          66.505817
# std                                            8.15511
#
#               Exports of goods and services (% of GDP)  \
# mean                                         10.885574
# median                                            7.05
# mode                                              4.03
# Q1:25th                                            5.2
# Q2:50th                                           7.05
# Q3:75th                                          18.69
# 99th                                            24.896
# Q4:100th                                         25.43
# IQR                                              13.49
# min                                               3.31
# max                                              25.43
# lower whisker                                  -15.035
# upper whisker                                   38.925
# skewness                                      0.717571
# kurtosis                                     -0.984549
# var                                          49.850062
# std                                           7.060458
#
#                Total reserves (includes gold, current US$)   \
# mean                                      98022273223.53476
# median                                   11511740598.809999
# mode                                           499145125.79
# Q1:25th                                        2324650346.6
# Q2:50th                                  11511740598.809999
# Q3:75th                                 137824828256.290009
# 99th                                    514172885263.065857
# Q4:100th                                590227359928.900024
# IQR                                     135500177909.690002
# min                                            499145125.79
# max                                     590227359928.900024
# lower whisker                          -200925616517.934998
# upper whisker                           341075095120.825012
# skewness                                           1.504361
# kurtosis                                           1.189566
# var                               22413140103987762036736.0
# std                                     149710187041.456085
#
#               Inflation, consumer prices (annual %)    Population, total  \
# mean                                       7.413279     891394550.147541
# median                                         6.67          870452165.0
# mode                                          -7.63            445954579
# Q1:25th                                        4.01          623524219.0
# Q2:50th                                        6.67          870452165.0
# Q3:75th                                       10.02         1154638713.0
# 99th                                         21.604         1388422080.8
# Q4:100th                                       28.6           1396387127
# IQR                                            6.01          531114494.0
# min                                           -7.63            445954579
# max                                            28.6           1396387127
# lower whisker                                -5.005         -173147522.0
# upper whisker                                19.035         1951310454.0
# skewness                                   0.964499             0.144009
# kurtosis                                    5.46447            -1.315477
# var                                       24.405109  88476293487744752.0
# std                                        4.940153     297449648.659642
#
#               Population growth (annual %)  \
# mean                              1.927705
# median                                2.15
# mode                                  2.23
# Q1:25th                               1.62
# Q2:50th                               2.15
# Q3:75th                               2.26
# 99th                                  2.34
# Q4:100th                              2.34
# IQR                                   0.64
# min                                   0.96
# max                                   2.34
# lower whisker                         0.66
# upper whisker                         3.22
# skewness                         -0.898885
# kurtosis                          -0.62215
# var                               0.175581
# std                               0.419024
#
#               Life expectancy at birth, total (years)
# mean                                         57.14623
# median                                          57.66
# mode                                            41.13
# Q1:25th                                         50.63
# Q2:50th                                         57.66
# Q3:75th                                         64.31
# 99th                                           69.592
# Q4:100th                                        69.73
# IQR                                             13.68
# min                                             41.13
# max                                             69.73
# lower whisker                                   30.11
# upper whisker                                   84.83
# skewness                                    -0.255398
# kurtosis                                    -1.073089
# var                                         71.564141
# std                                          8.459559

# %%
des_data["Inflation, consumer prices (annual %)"]
# Out:
# mean              7.413279
# median                6.67
# mode                 -7.63
# Q1:25th               4.01
# Q2:50th               6.67
# Q3:75th              10.02
# 99th                21.604
# Q4:100th              28.6
# IQR                   6.01
# min                  -7.63
# max                   28.6
# lower whisker       -5.005
# upper whisker       19.035
# skewness          0.964499
# kurtosis           5.46447
# var              24.405109
# std               4.940153
# Name: Inflation, consumer prices (annual %), dtype: object

# %%
def get_pdf_probability(dataset,startrange,endrange):
    from matplotlib import pyplot
    from scipy.stats import norm
    import seaborn as sns
    ax = sns.distplot(dataset,kde=True,kde_kws={'color':'blue'},color='Green')
    pyplot.axvline(startrange,color='Red')
    pyplot.axvline(endrange,color='Red')
    # generate a sample
    sample = dataset
    # calculate parameters
    sample_mean =sample.mean()
    sample_std = sample.std()
    print('Mean=%.3f, Standard Deviation=%.3f' % (sample_mean, sample_std))
    # define the distribution
    dist = norm(sample_mean, sample_std)
    
    # sample probabilities for a range of outcomes
    values = [value for value in range(startrange, endrange)]
    probabilities = [dist.pdf(value) for value in values]    
    prob=sum(probabilities)
    print("The area between range({},{}):{}".format(startrange,endrange,sum(probabilities)))
    return prob

# %%
get_pdf_probability(dataset["Inflation, consumer prices (annual %)"],1,5)
# Out:
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\ipykernel_launcher.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   """
# Mean=7.413, Standard Deviation=4.940
# The area between range(1,5):0.1968652911221671
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# 0.1968652911221671

# %%
def stdNBgraph(dataset):
    import seaborn as sns
    mean=dataset.mean()
    std=dataset.std()

    values=[i for i in dataset]

    z_score=[((j-mean)/std) for j in values]

    sns.distplot(z_score,kde=True)

    sum(z_score)/len(z_score)

# %%
stdNBgraph(dataset["Inflation, consumer prices (annual %)"])
# Out:
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\ipykernel_launcher.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   # Remove the CWD from sys.path while we load stuff.
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\axes\_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\axes\_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]

# %%
def freqTable(columnName,dataset):
    import pandas as pd
    frq=pd.DataFrame()
    frq["Unique_Values"]=dataset[columnName].value_counts().index
    frq["Frequency"]=dataset[columnName].value_counts().values
    frq["Relative_Fre"]=dataset[columnName].value_counts().values/len(dataset[columnName])*100
    frq["Cumulative"]=frq["Relative_Fre"].cumsum()
    return frq

# %%
freqTable("Inflation, consumer prices (annual %)",dataset)
# Out:
#     Unique_Values  Frequency  Relative_Fre  Cumulative
# 0            1.78          1      1.639344    1.639344
# 1           13.87          1      1.639344    3.278689
# 2            6.33          1      1.639344    4.918033
# 3           10.25          1      1.639344    6.557377
# 4           10.22          1      1.639344    8.196721
# ..            ...        ...           ...         ...
# 56           5.56          1      1.639344   93.442623
# 57           8.73          1      1.639344   95.081967
# 58           8.80          1      1.639344   96.721311
# 59           9.38          1      1.639344   98.360656
# 60           6.62          1      1.639344  100.000000
#
# [61 rows x 4 columns]
