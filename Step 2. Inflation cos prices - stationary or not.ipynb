# %%
import pandas as pd 
dataset=pd.read_csv("indianEco.csv")
dataset
# Out:
#     Year Country Name  GDP (current US$)    GDP per capita (current US$)   \
# 0   1960        India        3.702988e+10                              82
# 1   1961        India        3.923244e+10                              85
# 2   1962        India        4.216148e+10                              90
# 3   1963        India        4.842192e+10                             101
# 4   1964        India        5.648029e+10                             116
# ..   ...          ...                 ...                             ...
# 56  2016        India        2.294798e+12                            1733
# 57  2017        India        2.651473e+12                            1981
# 58  2018        India        2.702930e+12                            1997
# 59  2019        India        2.831552e+12                            2101
# 60  2020        India        2.667688e+12                            1928
#
#     GDP growth (annual %)  Imports of goods and services (% of GDP)  \
# ...

# %%
dataset['Year'] = pd.to_datetime(dataset['Year'], format='%Y')
dataset.set_index('Year', inplace=True)

# %%
dataset
# Out:
#            Country Name  GDP (current US$)    GDP per capita (current US$)   \
# Year
# 1960-01-01        India        3.702988e+10                              82
# 1961-01-01        India        3.923244e+10                              85
# 1962-01-01        India        4.216148e+10                              90
# 1963-01-01        India        4.842192e+10                             101
# 1964-01-01        India        5.648029e+10                             116
# ...                 ...                 ...                             ...
# 2016-01-01        India        2.294798e+12                            1733
# 2017-01-01        India        2.651473e+12                            1981
# 2018-01-01        India        2.702930e+12                            1997
# 2019-01-01        India        2.831552e+12                            2101
# 2020-01-01        India        2.667688e+12                            1928
#
# ...

# %%
df=dataset

# %%
df
# Out:
#            Country Name  GDP (current US$)    GDP per capita (current US$)   \
# Year
# 1960-01-01        India        3.702988e+10                              82
# 1961-01-01        India        3.923244e+10                              85
# 1962-01-01        India        4.216148e+10                              90
# 1963-01-01        India        4.842192e+10                             101
# 1964-01-01        India        5.648029e+10                             116
# ...                 ...                 ...                             ...
# 2016-01-01        India        2.294798e+12                            1733
# 2017-01-01        India        2.651473e+12                            1981
# 2018-01-01        India        2.702930e+12                            1997
# 2019-01-01        India        2.831552e+12                            2101
# 2020-01-01        India        2.667688e+12                            1928
#
# ...

# %%
df.to_csv("TS-inflation.csv",index=False)

# %%
import matplotlib.pyplot as plt
plt.plot(dataset["Inflation, consumer prices (annual %)"])

# %%
from pandas import read_csv
from matplotlib import pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
result = seasonal_decompose(dataset["Inflation, consumer prices (annual %)"], model='additive')
plt.figure(figsize=(16,5))
result.plot()
plt.show()

# %%
from statsmodels.tsa.stattools import adfuller
def adf_test(timeseries,df,pollutant):
    plt.figure(figsize=(16,5))
    # Plot the data
    # ADF Test
    # Function to print out results in customised manner
    from statsmodels.tsa.stattools import adfuller
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print (dfoutput)
    ans=dfoutput
    print("Condition:")
    print("p-value<=0.05-->Accept Alternate Hypothesis")
    print("p-value>0.05-->Accept Null Hypothesis")
    if(ans['Test Statistic']<ans["Critical Value (1%)"] or ans['Test Statistic']<ans["Critical Value (5%)"] or ans['Test Statistic']<ans["Critical Value (10%)"] and ans["p-value"]<0.05):
        print("Condition: statictic < any critical value and p-value <0.05 to reject null hypothsis")
        print("Reject null hypothesis:Non Stationarity")
        print("Accept Alternate hypothesis:Staionarity ")
        message="Stationarity based on ADH"
    else:
        print("Condition: statictic < any critical value and p-value <0.05 to reject null hypothsis")
        print("Accept null hypothesis:Non Stationarity" )
        print("Reject Alternate hypothesis:Staionarity ")
        message="Non-stationarity based on ADH"
        
    plt.plot(df.index, df[pollutant], label = pollutant)
    plt.legend(loc='best')
    plt.title("{}_{}_2013 to 2021".format(message,pollutant))
    plt.savefig("{}_ADH.png".format(pollutant))
    plt.show()
    
    return message

# %%
adf_test(dataset["Inflation, consumer prices (annual %)"],dataset,"Inflation, consumer prices (annual %)")
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                 -4.853444
# p-value                         0.000043
# #Lags Used                      4.000000
# Number of Observations Used    56.000000
# Critical Value (1%)            -3.552928
# Critical Value (5%)            -2.914731
# Critical Value (10%)           -2.595137
# dtype: float64
# Condition:
# p-value<=0.05-->Accept Alternate Hypothesis
# p-value>0.05-->Accept Null Hypothesis
# Condition: statictic < any critical value and p-value <0.05 to reject null hypothsis
# Reject null hypothesis:Non Stationarity
# Accept Alternate hypothesis:Staionarity
# C:\Users\Admin\anaconda3\envs\AIcoures\lib\site-packages\matplotlib\cbook\__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x[:, None]
# ...

# %%
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1,2,figsize=(16,3), dpi= 100)
plot_acf(dataset['Inflation, consumer prices (annual %)'].tolist(), lags=15, ax=axes[0])
plot_pacf(dataset['Inflation, consumer prices (annual %)'].tolist(), lags=15, ax=axes[1])
plt.show()

# %%
plt.plot(acf(dataset["Inflation, consumer prices (annual %)"],nlags=15))

# %%
plt.plot(pacf(dataset["Inflation, consumer prices (annual %)"],nlags=15))

# %%
from pandas.plotting import lag_plot
lag_plot(dataset["Inflation, consumer prices (annual %)"],lag=1)
